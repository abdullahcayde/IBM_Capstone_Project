# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Collecting Job Data Using APIs**

# %% [markdown]
# Estimated time needed: **45 to 60** minutes

# %% [markdown]
# ## Objectives

# %% [markdown]
# After completing this lab, you will be able to:

# %% [markdown]
# *   Collect job data from Jobs API
# *   Store the collected data into an excel spreadsheet.

# %% [markdown]
# > <strong>Note: Before starting with the assignment make sure to read all the instructions and then move ahead with the coding part.</strong>

# %% [markdown]
# #### Instructions

# %% [markdown]
# To run the actual lab, firstly you need to click on the [Jobs_API](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/module%201/Accessing%20Data%20Using%20APIs/Jobs_API.ipynb) notebook link. The file contains flask code which is required to run the Jobs API data.
#
# Now, to run the code in the file that opens up follow the below steps.
#
# Step1: Download the file.
#
# Step2: Upload it on the IBM Watson studio. (If IBM Watson Cloud service does not work in your system, follow the alternate Step 2 below)
#
# Step2(alternate): Upload it in your SN labs environment using the upload button which is highlighted in red in the image below:
# Remember to upload this Jobs_API file in the same folder as your current .ipynb file
#
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/module%201/Accessing%20Data%20Using%20APIs/Upload.PNG" />
#
# Step3:  Run all the cells of the Jobs_API file. (Even if you receive an asterik sign after running the last cell, the code works fine.)
#
# If you want to learn more about flask, which is optional, you can click on this link [here](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/module%201/Accessing%20Data%20Using%20APIs/FLASK_API.md.html).
#
# Once you run the flask code, you can start with your assignment.

# %% [markdown]
# ## Dataset Used in this Assignment
#
# The dataset used in this lab comes from the following source: [https://www.kaggle.com/promptcloud/jobs-on-naukricom](https://www.kaggle.com/promptcloud/jobs-on-naukricom?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2022-01-01) under the under a **Public Domain license**.
#
# > Note: We are using a modified subset of that dataset for the lab, so to follow the lab instructions successfully please use the dataset provided with the lab, rather than the dataset from the original source.
#
# The original dataset is a csv. We have converted the csv to json as per the requirement of the lab.

# %% [markdown]
# ## Warm-Up Exercise

# %% [markdown]
# Before you attempt the actual lab, here is a fully solved warmup exercise that will help you to learn how to access an API.

# %% [markdown]
# Using an API, let us find out who currently are on the International Space Station (ISS).<br> The API at [http://api.open-notify.org/astros.json](http://api.open-notify.org/astros.json?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2021-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ) gives us the information of astronauts currently on ISS in json format.<br>
# You can read more about this API at [http://open-notify.org/Open-Notify-API/People-In-Space/](http://open-notify.org/Open-Notify-API/People-In-Space?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2021-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)

# %%
import requests # you need this module to make an API call
import pandas as pd

# %%
api_url = "http://api.open-notify.org/astros.json" # this url gives use the astronaut data

# %%
response = requests.get(api_url) # Call the API using the get method and store the
                                # output of the API call in a variable called response.

# %%
if response.ok:             # if all is well() no errors, no network timeouts)
    data = response.json()  # store the result in json format in a variable called data
                            # the variable data is of type dictionary.

# %%
print(data)   # print the data just to check the output or for debugging
# Out:
# {'number': 14, 'message': 'success', 'people': [{'name': 'Kjell Lindgren', 'craft': 'ISS'}, {'name': 'Bob Hines', 'craft': 'ISS'}, {'name': 'Samantha Cristoforetti', 'craft': 'ISS'}, {'name': 'Jessica Watkins', 'craft': 'ISS'}, {'name': 'Cai Xuzhe', 'craft': 'Tiangong'}, {'name': 'Chen Dong', 'craft': 'Tiangong'}, {'name': 'Liu Yang', 'craft': 'Tiangong'}, {'name': 'Sergey Prokopyev', 'craft': 'ISS'}, {'name': 'Dmitry Petelin', 'craft': 'ISS'}, {'name': 'Frank Rubio', 'craft': 'ISS'}, {'name': 'Nicole Mann', 'craft': 'ISS'}, {'name': 'Josh Cassada', 'craft': 'ISS'}, {'name': 'Koichi Wakata', 'craft': 'ISS'}, {'name': 'Anna Kikina', 'craft': 'ISS'}]}

# %% [markdown]
# Print the number of astronauts currently on ISS.

# %%
print(data.get('number'))
# Out:
# 14

# %% [markdown]
# Print the names of the astronauts currently on ISS.

# %%
astronauts = data.get('people')
print("There are {} astronauts on ISS".format(len(astronauts)))
print("And their names are :")
for astronaut in astronauts:
    print(astronaut.get('name'))
# Out:
# There are 14 astronauts on ISS
# And their names are :
# Kjell Lindgren
# Bob Hines
# Samantha Cristoforetti
# Jessica Watkins
# Cai Xuzhe
# Chen Dong
# Liu Yang
# Sergey Prokopyev
# Dmitry Petelin
# Frank Rubio
# Nicole Mann
# Josh Cassada
# Koichi Wakata
# Anna Kikina

# %% [markdown]
# Hope the warmup was helpful. Good luck with your next lab!

# %% [markdown]
# ## Lab: Collect Jobs Data using Jobs API

# %% [markdown]
# ### Objective: Determine the number of jobs currently open for various technologies  and for various locations

# %% [markdown]
# Collect the number of job postings for the following locations using the API:
#
# *   Los Angeles
# *   New York
# *   San Francisco
# *   Washington DC
# *   Seattle
# *   Austin
# *   Detroit

# %%
#Import required libraries
import pandas as pd
import json

# %% [markdown]
# #### Write a function to get the number of jobs for the Python technology.<br>
#
# > Note: While using the lab you need to pass the **payload** information for the **params** attribute in the form of **key** **value** pairs.
#
# Refer the ungraded **rest api lab** in the course **Python for Data Science, AI & Development**  <a href="https://www.coursera.org/learn/python-for-applied-data-science-ai/ungradedLti/P6sW8/hands-on-lab-access-rest-apis-request-http?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2022-01-01">link</a>
#
# ##### The keys in the json are
#
# *   Job Title
#
# *   Job Experience Required
#
# *   Key Skills
#
# *   Role Category
#
# *   Location
#
# *   Functional Area
#
# *   Industry
#
# *   Role
#
# You can also view  the json file contents  from the following <a href = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/module%201/Accessing%20Data%20Using%20APIs/jobs.json?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2022-01-01">json</a> URL.

# %%
api_url="http://127.0.0.1:5000/data"
def get_number_of_jobs_T(technology):
    number_of_jobs = 0
    page=0
    new_results=1
    while new_results>0:
        payload={"Job Title":technology,"page":page}
        r=requests.get(api_url,payload)
        new_results =len(r.json())
        page+=1
        number_of_jobs+=(len(r.json()))
    return technology,number_of_jobs
    #your code goes here
    return technology,number_of_jobs

# %% [markdown]
# Calling the function for Python and checking if it works.

# %%
get_number_of_jobs_T("Python")

# %% [markdown]
# #### Write a function to find number of jobs in US for a location of your choice

# %%
def get_number_of_jobs_L(location):
    number_of_jobs = 0
    page=0
    new_results=1
    while new_results>0:
        payload={"Location":location,"page":page}
        r=requests.get(api_url,payload)
        new_results =len(r.json())
        page+=1
        number_of_jobs+=(len(r.json()))
    return technology,number_of_jobs
    #your code goes here
    return location,number_of_jobs

# %% [markdown]
# Call the function for Los Angeles and check if it is working.

# %%
#your code goes here
get_number_of_jobs_L("Los Angeles")

# %%
# My Solution 
# I have problem to connect api_url because of that i use api2_url .

api2_url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/module%201/Accessing%20Data%20Using%20APIs/jobs.json?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2022-01-01"
r = requests.get(api2_url)
data = r.json()

# %%
len(data)
# Out:
# 27005

# %%
# Functions 

def get_number_of_jobs_T(technology):
    #global technology
    #r = requests.get(api2_url)
    #data = r.json()
    number_of_jobs = 0
    for i in range (0,len(data)):
        if (technology in  data[i]["Key Skills"]):
            number_of_jobs += 1
    return technology,number_of_jobs

print(get_number_of_jobs_T("Python"))

def get_number_of_jobs_L(location):
    number_of_jobs = 0
    for i in range (0,len(data)):
        if location in  data[i]["Location"]:
            number_of_jobs += 1
    return location,number_of_jobs

print(get_number_of_jobs_L("Los Angeles"))

def get_number_of_jobs_J_and_L(technology,location):
    number_of_jobs = 0
    for i in range (0,len(data)):
        if (technology in  data[i]["Key Skills"]) and (location in  data[i]["Location"]):
            number_of_jobs += 1
    return technology,location,number_of_jobs

print(get_number_of_jobs_J_and_L("C#", "Los Angeles"))
# Out:
# ('Python', 1173)
# ('Los Angeles', 640)
# ('C#', 'Los Angeles', 5)

# %%
# All Locations
l = []
for i in range (0,len(data)):
    l.append(data[i]["Location"])
print(set(l))
# Out:
# {'San Francisco', 'Philadelphia', 'Baltimore', 'Austin', 'Los Angeles', 'New York', 'Washington DC', 'Houston', 'New Orleons', 'Dallas', 'Detroit', 'Seattle', 'Boston'}

# %%
data[100]["Key Skills"].split("| ")
# Out:
# ['Voice process', 'qaqc', 'Writing', 'Process operations', 'Verbal']

# %%
def get_number_of_jobs_T(technology):
    #global technology
    #r = requests.get(api2_url)
    #data = r.json()
    number_of_jobs = 0
    for i in range (0,len(data)):
        if (technology in  data[i]["Job Title"]):
            number_of_jobs += 1
            print(i,data[i]["Job Title"])
            print(data[i]["Key Skills"], "\n")
    return technology,number_of_jobs

get_number_of_jobs_T("Data")
# Out:
# 52 Oracle DBA Consultant - Data Guard/rac Modules
# WebLogic| configuration| MySQL| installation| Oracle DBA| troubleshooting| Oracle RAC
#
# 154 Associate Clinical Data Processor
# MS Office| Data entry
#
# 354 Data Science Engineer
# Unix| data science| SQL| Linux| SAS| HTML| Perl| SDLC| Android|Python
#
# 358 Senior Data Analyst
# Reporting| Data Analysis| Business Analytics| Data Analytics| kpo
#
# 366 Data Science Manager
# kaggle|NLP|data science|Artificial Intelligence|Natural Language Processing|analytical techniques|Text Mining|big data|machine learning|Deep Learning
#
# 421 Data Scientist - Sql/nosql
# SQL| NoSQL| R|Python| Scala| Data Visualization| Machine Learning| Data Science| Data Modeling| Algorithm
#
# 431 Senior Java Tech Lead - Spring Boot/ Data Structure
# Java| SOA| TDD| SaaS| J2EE| Spring Boot| API| Algorithm| Data Structure
#
# 433 ETL Datastage Developer
# Technical Management| Agile Methodology| Unit Testing| Design Development| Business Analytics| Big Data| SQL Queries| Spark| Performance Tuning| Test Case Design
#
# 482 Real Estate Surveyors/Data Collection Executive
# Help Desk| Customer Service| customer relationship| access controls| Asset Management| Vendor Management
#
# 528 Reference Data Operations - Senior Team Member
# Service level| operational support| Financial reporting| project support| Helpdesk| Issue resolution| Risk management| Operations| Project life cycle| Downstream
#
# 606 Data Management Developer - Ssis/ssrs
# SSIS| SSRS| Technical Training| Data Management| SQL| software development
#
# 625 Sr. Data Engineer Human Resources
# Unix| Maven| Automation| Linux| Data modeling| Infrastructure management| Agile| Application development| Apache| Information technology
#
# 656 Data Entry Operator,
# data entry operation| organization skills| us healthcare| Data Entry| ms office| typing speed
#
# 680 Data-Researcher-I
# Financial reporting| Analytical| Market intelligence| Accountancy| Data research| Finance| Internet searching| Credit risk| MS Office
#
# 721 Role 1 : Data Scientist
# Linux|Python| Coding| Open source| Machine learning| big data| Basic| spark| hdfs| SCALA
#
# 828 Senior Engineer, Big Data &amp; Security
# development| junit| java| apache| jboss| tomcat| product development| mysql| eclipse
#
# 841 Data Analyst
# Data Analysis| Data Analyst| reporting| Quality Control
#
# 855 Required Data Entry Operator/computer Operator
# Data Entry Operation| Computer Operating| Data Management| data analysis| Data Entry| computer operator| back office| non voice| backend| kpo
#
# 875 Principal Engineer - Java/big Data
# Java| Open Source| Scala| Big Data| Spark| Performance Tuning|Python
#
# 885 Lead Data Scientist
# Python| Machine learning| Forecasting| Text mining| Neural networks| Natural language processing| text analytics| Logistic regression| advanced analytics| deep learning
#
# 888 Data Information Management Intermediate Analyst
# SAS| MIS| Financial services| Automation| Analytical| Cognos| Business strategy| Information management| Information technology| Data extraction
#
# 895 SAP MM Consultant For NTT Data,bangalore C2H Hiring
# Interfaces| idocs| sap mm| problem solving
#
# 951 Team Lead - Data Governance
# IT services| Automation| data governance| Team Leader| Financial services
#
# 1026 Data Researcher
# Monitoring| Social networking| Data research
#
# 1064 Hiring For Data Entry & Computer Operator Jobs In Ohio New York
# Data Entry| Computer Operating| Calling| customer care| customer support| customer service| customer service executive| customer support executive| Domestic BPO| call center executive| customer care executive| customer care officer| customer support officer
#
# 1135 Senior Data Scientist
# Python| Business intelligence| Coding| Computer science| Machine learning| Hbase| MongoDb| NoSQL| Cassandra| Operations
#
# 1149 Lead Data Analyst
# Analytics| Monitoring| SQL| Computer science| Process automation| Automation| Assurance| Analytical| Predictive modeling| Business solutions
#
# 1196 Mysql Database Developer in Malad Location.
# database development| MySQL Db| mysql database| Stored Procedures| triggers| functions
#
# 1215 Big Data Engineer
# Java|Hadoop|Python|C++|Spark|Machine Learning|NoSQL|Oozie|Big Data|Languages
#
# 1256 Sybase Database Administrator
# production support| build automation| dba| performance tuning| sybase iq| redhat linux| perl| database administration| unix
#
# 1270 Big Data Developer - Tableau/Python/r
# Tableau| SAS| R|Python| Spark| Machine Learning| RDBMS| SQL| Hadoop| Startup| Big Data
#
# 1304 Senior Big Data Support Analyst
# SQL| Application support| Incident management| Service management| Operations| Informatica| Support services| Teradata| Service level| Back office support
#
# 1339 Senior Data Scientist Bidgely
# Computer science| Data analysis| Analytical| Machine learning| Tools| Data mining| MATLAB| Monitoring| Analytics|Python
#
# 1376 Data Governance
# MDM| Metadata| Master Data Management| Edw| Data Governance
#
# 1454 Senior Oracle Database Administrator - Production Support
# Oracle DBA| DBA| Production Support| Technical Consultant| Oracle RAC
#
# 1464 Lead Data Analytics
# statistical modeling| data analytics| data visualization| fraud analytics| business intelligence| communication skills| excel| advanced excel
#
# 1501 Network Engineer - Datacenter
# Network Administration| Datacenter| WLAN| Project Management| OSPF| BGP| MPLS| EIGRP| FCOE| LACP
#
# 1609 Database Administrator - Data Modeling
# DBA| RDBMS| Windows Server| Data Modeling| DBMS| Performance Tuning| SQL| Performance Monitoring
#
# 1635 Hiring For Database Developer
# Power Bi| Data Modeling| Database Development| SQL
#
# 1640 Data Scientist
# Networking| MIS| Information security| SIEM| Database| Data analytics| big data| IPS| Security monitoring
#
# 1671 Big Data Architect - Azure - IT
# Data Architect| Data Management| Big Data| Data Visualization| Data Warehousing| Data Analytics| Machine Learning| Analytics| SQL
#
# 1682 Vacancy For Freelancer Work From Home / Part Time 5 Types Data Entry
# bpo| freelancing| freelance writing| data mining| data processing| notepad| administration work| kpo| part time| data entry operation| excel| data extraction| typing| content writing| non voice| data entry
#
# 1700 Databases Testing Engineers
# oracle| sql server| development| mca| performance testing| mercury| database testing| testing databases| middleware testing
#
# 1744 Online Marketing Executive and Data Entry
# sales management| online sales| sales| auto parts| accessories| Warehouse Operations| Data Entry| Sales Lead Generation
#
# 1782 Database Administrator
# Unix| Hibernate| Installation| Linux| RDBMS| Billing| MySQL| Operations| Tuning| Technical documentation
#
# 1786 Senior Database Administrator & Data Modeler
# ETL| Modeler| Test Case Design| Datastage| Data Modeling| Performance Tuning| Unit Testing| Design Development| Business Process| Application Development
#
# 1819 Walk-in- Sat-22nd June- Research Associate- Private Market Data
# investment research| equity research| financial research| mba finance| investment banking| venture capital| private equity| cfa| data analyst| financial analyst
#
# 1871 Field Data Collection Executive
# Sales| Field Sales| data collections| Data Collection| Courier
#
# 1899 Data Engineer - Aryaka Bangalore
# hive|Python| java| mapreduce| spark| cassandra| mysql| big data| hbase| pig
#
# 1903 Datawarehousing Architect Database expert
# Informatica| Cognos| Datastage| PLSQL| Data structures| Workflow| Data modeling| RDBMS| Stored procedures| Data migration
#
# 1924 Guidewire Developer - Data Modeling
# Integration| UI| Application Integration| Data Modeling| Guidewire
#
# 1974 Urgent Need Hindi Call Center | BPO | CCE | Data Entry Fresher Apply
# BPO| Cce| Calling| Inbound| Data Entry| fresher| voice process| chat| Back Office| Domestic BPO| backend| Call Center| International BPO
#
# 2024 ETL Datastage Developer
# c++| C| design| MySQL| JavaScript| HTML
#
# 2028 Data Entry|typing|copy Paste|smssending Job Online/offline
# freelancing| data entry operation
#
# 2044 Data Engineer
# Data Science| Java| NoSQL|Python| Spark| Artificial Intelligence| Machine Learning| Hadoop| SCALA| R
#
# 2142 Data Visualization Manager
# Project management| Analytics| Recruitment| Data analysis| Data management| Business research| Consulting| RFP| Macros| Client management
#
# 2216 Project Manager Database
# sql server| database design| hive| finance| project management| development testing| project manager| Database
#
# 2218 Data Entry, Back Office, Computer Operator
# English| Data Entry| Computer Operating| Back Office| Selection Process| Domestic BPO| bpo call center| bpo fresher
#
# 2285 Datastage Developer @-
# Datastage| Datastage Developer
#
# 2310 SQL Database Administrator
# SQL Server Administration| SQL Database| MS SQL Server
#
# 2317 Lead Administrator Database Infrastructure
# Performance tuning| Service| Consulting| Trend analysis| English language| Customer satisfaction| Oracle admin| Effort estimation| Lead Administrator| Database Administrator
#
# 2438 Data Analytics
# Unit testing| Monitoring| Computer science| Software configuration management| Performance management| Service level| Data analytics| Architecture| Resource planning| software architecture
#
# 2560 Opening For Database Architect at Landis Gyr Ltd. New York
# Query Optimization| Database Administration| Transition Management| Cassandra| SQL Server| Performance Tuning| Optimization| Oracle RDBMS| PLSQL| Data Modeling| Data Warehousing| Data Architecture| OLTP
#
# 2686 Hiring for Data Entry
# Data Entry| typing| computer operator| back office
#
# 2695 Sr.engineer - Data Modeling
# Enterprise Architecture| High Availability| Data Management| BI| OLAP| SQL| Data Model| DATA BASE| Data Analysis| Physical Design| Data Modeling| ETL| ERWIN
#
# 2700 Datawarehouse Developer/ Lead
# C|Python| Six Sigma| PMP| .NET| HTML| JavaScript| SQL| Oracle| assembly language| Real Time Operating Systems
#
# 2750 Assistant Manager – Data Analysis & Reporting Role
# tableau|data analysis|design development|vba|ms sql server|management reporting|sql
#
# 2760 Home Based Data Entry,sms Sending, Copy Paste Online Work from Home
# Word| Typing| freshers| part time| data entry
#
# 2866 Data Analyst or Analyst
# Analyst| Product enhancement| Customer experience| e - Commerce| conversion
#
# 2923 Corporate Master Data Governance. MDG Enrichment & Cleansing
# Team Management| Data Enrichment| SAP| Data Migrations| Data Cleansing| Data quality| Master Data| Data Profiling| hana| Data Governance
#
# 2966 SQL Server Database Administrator
# Data management| RDBMS| SSRS| OLAP| Application development| SSIS| Troubleshooting| Information technology| Technical support| SQL
#
# 2970 Amazon Hiring Data Associate- Phoenix Avance-hitech City
# annotation|communication skills|fresher|data services|transcriber|Cbse|ICSE
#
# 3004 Senior Specialist – Data Reference Division (2 – 5years)
# Power Bi|SQL|Data Integration|Data Reporting|People Development|Management Services|Leadership Hiring|Maintenance Activities|Continuous Improvement|Client Satisfaction
#
# 3130 Oracle Application Database Administrator
# High Availability| MS SQL| R12| Database Administration| Linux| RAC| EBS| Oracle Apps Dba| 11I| Golden Gate
#
# 3206 Excellent Opportunity in Data Analytics [bangalore
# etl| data modeling| data visualization| data warehousing| dw| data analytics| sas| data reporting| data analysis| cloud| Bi| Big Data
#
# 3334 Deputy Manager/manager - Data Consultant
# functional testing| process integration| business understanding| stakeholder management| process improvement initiatives| version control| business development| strategy| performance management
#
# 3364 AWS Architect - Data & Analytics
# Data Analytics| Big Data
#
# 3377 Junior Linux/c++ Developer - Data Structure/sqlite
# C++| Multithreading| Linux| Data Structures| SQLite| Memory Management| Algorithm| Data Structure
#
# 3414 Tivoli/ Netcool Support Engineer - Data Warehousing
# itm| performance tuning| data warehousing| tivoli| netcool omnibus| middleware
#
# 3442 Data Engineer
# Python| Six Sigma| .NET| HTML| JavaScript| SQL| Oracle| assembly language| Real Time Operating Systems
#
# 3471 BigData Developer
# Java| HADOOP| Scala| SPARK
#
# 3495 Urgent Hiring for Data Center Operator for New Jersey Location.
# Networking| Windows Server| ITIL Certified| Backup Management| Data Center| End User| Computer Operating
#
# 3716 Senior Data Scientist For a Product Based Company, New Jersey
# Java| C++| Software Development| Algorithms| Languages| Machine Learning|Python
#
# 3732 Database Developer 1
# SQL|Excel|QC|QA|Database Development|Data Validation|Process Improvement
#
# 3763 Big Data Engineer
# Linux|Python| Agile| Configuration management| HTTP| JIRA| Japanese| SMTP| Version control| SCALA
#
# 3790 Data Analyst II
# Adobe| Data mining| Executive| SQL queries| big data| Data Analyst| Analyst II| tableau| Hadoop
#
# 3813 Data Entry Excutive
# Product training| Basic| data integrity| Data entry
#
# 3820 Big Data Architect
# Hive| Elastic search| big data| Hbase| Apache Spark
#
# 3881 Walkin Interview For Freshers in Data Entry Operator Process
# bpo| Inbound Process| Email Support| Computer Operator| back office| back office executive| call center| Data Entry Operator| Marketing| Chat Process| Backend| voice process| Domestic BPO| Fresher| data entry
#
# 3945 Lead / Senior Staff Hadoop Engineer , Data Platform
# Automation| GIT| SAS| Db2| Configuration management| Analytical| Data processing| Open source| JIRA| Operations
#
# 3956 Hiring In Bank Back Office Data Entry
# data entry operation| bpo| computer operator| back office| back office operations| office assistant| back office executive| typing| data entry| banking
#
# 3962 MIS Executive / Data Analyst
# web technologies| data entry| CRM| Data Analysis| data mining
#
# 4212 Big Data For New Jersey Location
# Java| NoSQL| Neo4J| SCALA| Big Data| Spark| HBase|Python
#
# 4259 Data Scientist / Data Science Trainer -Python & R - Deep Learning
# Data Science| Deep Learning| R|Python| Statistics| SAS
#
# 4315 Senior Teradata Database Administrator
# Teradata| DBA| Database Administration
#
# 4380 opening for Data Scientist_Hyderabad
# SQL| HIVE|Python| R| Shell| Shell.
#
# 4496 Lead Administrator Database Infrastructure
# Performance tuning| Service| Consulting| Trend analysis| English language| Customer satisfaction| Oracle admin| Effort estimation| Lead Administrator| Database Administrator
#
# 4606 Cloud Data Engineer
# Usage| GIT| Business transformation| Linux| Machine learning| Agile| Cost| AWS| SQL|Python
#
# 4708 Big Data Developer
# Hive| Sqoop| Hadoop| Big Data
#
# 4718 ERP Database Engineer (green Park, South Ohio)
# technical support| data modeling| product life cycle| presentation skills| analytical skills| sql server| problem resolution| SQL Developer| sql database
#
# 4745 Back-Office-&-Data-Entry-Operator
# Com| advertising agency| Typing speed| Back office| MS Office| Ad agency| Advertising| Application| Data entry| Data Entry Operator
#
# 4923 Site Reliability Engineer - Data Infrastructure
# Linux| Perl| Automation|Python| SAN| Open source| Ruby| Analytics| Data management| Computer science
#
# 5003 Data Scientist
# SAS| Hadoop| R| Hive| SQL| Machine Learning| Time Series| Big Data Analytics| Predictive Modeling| Statistics
#
# 5147 Data Engineer
# Root cause analysis| metadata| Data management| query| Data structures| Management| big data| Data warehousing| Analytics| SQL
#
# 5173 Sr. Data Analyst- Tableau, Sql Analyst
# data warehouse| Tableau| ETL| SQL
#
# 5229 Associate Director, Global Data Analytics Delivery
# MIS| Consulting| Back office| Supply chain| IT services| Automation| Information security| Data quality| IT operations| Information technology
#
# 5230 Data Developer
# Six Sigma| .NET|Python| assembly language| JavaScript| HTML| developer| Oracle| email| SQL
#
# 5231 SAP Business Objects Data Services
# Data Services|Application Development|Performance Testing|Business Process|Business Objects|Data Migration
#
# 5295 EDI (electronic Data Interchange)
# Unix|Supply chain|Service management|FTP|Shell scripting|Problem management|EDI|Troubleshooting|Unix shell scripting|Python
#
# 5305 Great Opportunity For Big Data Developer@ Captive
# hive| java| spark| scala| hadoop| data architecture| big data| communication skills
#
# 5314 Data Migration Engineer
# Troubleshooting| SQL| Coding| Computer science| PDF| Data migration| Ruby| Pentaho| continuous integration| Programming
#
# 5402 Data Science Consultant - Real World Evidence
# data science| Project planning| Analytics| Operations research| Publishing| Analytical| Machine learning| HTML| Mining operations| Data mining
#
# 5422 Network Data Security Operations Engineer requirements Florida
# Data Security| Security Operations| CISCO| Cisco Wireless
#
# 5439 SMS Sending Job Online Typing Work Data Entry Work from Home SMS Jobs
# Word| Typing| freshers| part time| data entry
#
# 5492 Need Executives For Computer Operator/ Data Entry Operator - Freshers
# Back Office Processing| BPO| Data Entry| Call Center| Cce| Calling| Domestic| customer care| inbound| executive| customer service| customer support| kpo| voice process| fresher| domestic bpo| international bpo| customer care executive
#
# 5500 Sr Clin Data Coordinator
# Data management| Design review| EDC| Process improvement| Healthcare| QIP| Continuous improvement| Analytics| IMS
#
# 5586 Senior- Database- Administrator
# Performance tuning| MS SQL| Postgresql| Database administration| Agile| Windows| Oracle| Troubleshooting| SDLC| Monitoring
#
# 5725 Data Scientist
# data mining| mapping| business intelligence| Data modeling| Statistical analysis| machine learning|Python| R| MATLAB
#
# 5737 Database Migration Specialist
# Computer science| Postgresql| MySQL| Test planning| Performance optimization| Customer service| Dms| professional services| Troubleshooting| PGSQL
#
# 5743 Data Base Developer
# MS SQL| Data modeling| SSRS| Agile| Database| Visual Studio| SSIS| Business Executive
#
# 5903 Data Transfer operator
# Computer hardware| Networking| MS Office| Hardware networking| IT support| Hardware| HR| it| microsoft
#
# 5924 Need 10th/12th Pass Freshers For Call Center | BPO | Data Entry | CCE
# International BPO| Call Center| Non Voice Process| Customer Care| Calling| Domestic| inbound| voice process| international call center| BPO| KPO| LPO| Domestic BPO
#
# 5948 Associate Manager / Manager Data Scientist
# Associate Manager / Manager Data Scientist
#
# 6037 Associate - Controls Room Business Analyst & Data Management
# Change management| Data management| Wealth management| Business analysis| Project management| operational risk management| Asset management| Financial services| Auditing| Business operations
#
# 6055 Data Entry | Back Office Executive | Fresher | Computer Operator
# BPO| Hiring| LPO| call center| KPO| Data Entry| bpo call center| Communication Skills| Backend| bpo fresher| Bpo Voice| chat| Domestic| Domestic BPO| bpo executive| international call center| International BPO
#
# 6081 Data Conversion
# Customer Service| Help Desk| Information| Telephony support| customer relationship| access controls| Vendor Management| Asset Management
#
# 6119 Call Center / Fresher/ Calling /customercare / BPO/ Data Entry
# bpo| Inbound Process| Customer Service| Incentives| International Call Center| cce| inbound| Computer Operating| Calling| Voice Process| Non Voice| Data Entry| Customer Care Executive| Back Office| Telecalling| Customer Care| Domestic BPO| Chat
#
# 6160 AppZen, Inc. - Foreign Language Data Analyst
# Japanese| Business process| Pharma| Aerospace| German| French| Spanish| Computer vision| Customer experience| Compliance
#
# 6166 Lead Administrator - IMS - DB2UDB Database Infrats-L4.1
# Db2| IMS| Module| Project delivery| Entry level| Lead Administrator| Language skills| Application| Manager Technology
#
# 6171 Urgent Opening for "ICT Manager for Data Center
# data center| mcse| ccna| oem| pmp trained| UNIX| Linux| Servers| Network| Storage| Backup
#
# 6472 Manager- Data Science
# Data Science| SAS SQL| Secondary Research| Excel Powerpoint| Artificial Intelligence| Research Analysis| Advanced Analytics| Data Analysis| Team Leading| People Management| Primary Research|Python
#
# 6501 Data Architect
# SSIS| SSRS| SQL Server| Power Bi| Data Modeling| Data Warehousing| Oracle| DW| Tableau| QlikView
#
# 6535 Java with Big Data Professional
# java| hadoop| hive| j2ee| spring boot| mockito| hbase| pig| junit| microservices| sql| Git| Jenkins
#
# 6557 Administrator - IMS - Network Cisco Data-L3.1
# cisco| IMS| RCA| Trend analysis| Subject matter expertise| Hardware troubleshooting| Customer satisfaction| Senior Administrator| Effort estimation| Training
#
# 6581 Master Data Management (talend/kalido/reltio/others)
# Business process|Data migration|SAP|Networking|Master data management|Manager Technology|Outsourcing|Oracle|Operations
#
# 6614 Data Anaylst- Fresher
# Pharma| Book Keeping| Auditing
#
# 6622 Data Scientist
# Data Scientist
#
# 6642 Senior Database Developer
# SQL| Senior| Oracle| Performance tuning| server| development| SAP| development testing| Database design| testing| Indesign| database| design| Design development| developer| Indexing| architecture
#
# 6718 Looking For Data Analyst
# Data Analysis| Data Mining| Analytics| Advanced Excel
#
# 6761 Lead Administrator Database Infrastructure
# Performance tuning| Service| Consulting| Oracle RAC| Trend analysis| English language| Customer satisfaction| Vmware Administrator| Effort estimation| Lead Administrator
#
# 6762 Cisco Data & Voice Network Administrator
# Administrator| Network| LAN| WAN| Windows| Servers| SQL
#
# 6871 Sr. Administrator - Database
# Networking| Oracle| Troubleshooting| Performance tuning| Network administration| FTP| Release management| RMAN| Monitoring| Auditing
#
# 6874 Apple - Software Engineer - Big Data - Scala/spark
# Jenkins| Java| Hadoop| Javascript| JSON| Bash| Spark| Groovy| Play Framework|Python
#
# 6882 Senior Manager - Data Analytics/sas - Banking Firm
# NLP| SAS| Data Management| Data Analytics| Statistics| Machine Learning| Analytics| Business Analysis| Predictive Analytics
#
# 6892 Senior Database Administrator - CMMI Level 5 | Immediate Requirement
# High Availability| Windows Server| Disaster Recovery| Restore| Active Directory| MySQL Database Administration| MS SQL| NoSQL| MySQL| HA| MongoDB| AWS
#
# 6894 Big Data Software Quality Engineer
# Unix| Load testing| Software development life cycle| Scrum| Selenium| Test cases| software quality| Teradata| Continuous improvement| big data
#
# 6935 Data Scientist
# nlp| data science
#
# 6938 Assistant Manager – Data Analysis & Reporting Role
# data modeling|ms sql server|data analysis|tableau|data warehousing|business analytics|management reporting|design development|tableauu
#
# 6981 Senior Data Scientist
# advanced analytics| r|Python| data analysis| neural networks| machine learning
#
# 7050 Java Developer - Backend Development - Data Structure/algorithm
# Java| Maven| Hibernate| Design Patterns| J2Ee| JEE| JMS| Rest| Algorithms| Spring Framework| JPA
#
# 7117 HUGE Openings For MIS Executive / Data Analyst / Direct Walk IN
# new projects| operations management| mis preparation| data analysis| mis reporting| formulas| pivot table| vlookup| warehouse| excel powerpoint| vba| mis| supply chain management| database analyst| bpo operations
#
# 7130 DataStage Developer
# Unix| Linux| Datastage| Oracle database| Data warehousing| Oracle SQL
#
# 7138 SSE Big Data - ETL
# MongoDB| Unix| Linux| MySQL| Informatica| UML| Datastage|Python| Data structures| Data modeling
#
# 7211 Jr. Data Scientist
# Predictive Modeling| Big Data Analytics| Hadoop| Spark| Predictive Analytics
#
# 7260 Senior Data Engineer |Python | Big Data
# activemq| GIT| Analytical| MySQL| Data structures| MongoDB| Analytics| SQL|Python| Technical documentation
#
# 7348 Urgent Requirement Data analytics Openings On Top MNC,Bangalore
# SQL| Java|Python| R| Software Development| VBA| Advanced Excel| Data Analytics| C#| Predictive Modeling
#
# 7354 Open Stack/ Datacenter Expert - Linux/ Docker
# Ubuntu| Linux| Docker| Datacenter| System Administration| OpenStack| RHEL| CentOS
#
# 7370 Senior Data Engineer
# SQL| Automation|Python| Agile| System administration| Monitoring| Customer support| Computer science| Machine learning| Analytical
#
# 7386 Sr. Data Scientist - R,Python, Machine Learning
# R| SAS| GCP| Cloud| Big Data| Machine Learning| AWS|Python
#
# 7466 Data Architect
# quality processes| data warehouse| large| enterprise| procedures| data architecture| designing
#
# 7489 Big Data Developer / Big Data Lead Developer /Big Data Architect
# Apache| Linux| PHP| development| technical| software| Social media| developing| HBase| nosql| cloud| scripting| project support| RDBMS| design| developer| hadoop| Open source| Ruby| Pentaho| support| architecture| applications| hardware
#
# 7506 Data Quality Profiling - Associate
# Excel| Data management| EMEA| Project management| Data quality| Application development| Informatica| SQL| Cdo| data profiling
#
# 7546 Opening for Network Data & Security for New York_Contract Position
# Check Point| Cisco| Palo Alto
#
# 7702 Data Collection Executive
# Customer Service| Help Desk| Information| Telephony support| customer relationship| access controls| Vendor Management| Asset Management
#
# 7777 Data Analyst/data Scientist - C++/c#/java
# Java| C++| C#| Machine Learning| Solution Architect| Hadoop| Data Analyst
#
# 7804 Data Architecture Principles
# R|SAS|Data Analysis|Big Data|Data Collection|Data Modeling|Data Architecture|Data Analytics|ETL|Data Governance
#
# 7855 Need Fresher for Data Entry Operator / CCE Under BPO Company
# BPO| Data Entry Operation| Cce| Inbound| Calling| Domestic| Night Shift| international bpo| bpo fresher| domestic bpo| telecaller| tele marketing executive| tele calling executive| BPO Hiring| bpo recruitment
#
# 7942 DataScientist- Vice President
# Computer science| Capacity management| Machine learning| Agile| Data mining| MATLAB| Monitoring| Financial services| SQL|Python
#
# 8065 Practice Head - Data Analytics Solutions - Arizona
# Telecom| Senior management| Networking| sales enablement| Flex| Database| Data analytics| Executive search| Key account management
#
# 8108 Engineer- Product Data Management
# PLM| Production engineering| Process improvement| Data Analyst| Product data management| Siemens| Interpersonal skills| Excel| ERP system| Product life cycle management
#
# 8198 Data Analyst
# Market research| Data analysis| SQL| Logistics| Ideas| Income tax| Tax returns| Data Analyst| Business Executive| Corporate tie-ups
#
# 8280 Data Scientist
# C++| SAS|Python| Data analysis| Prototype| cassandra| Analytical| SPSS| data visualization| big data
#
# 8304 Home Based SMS Sending Work Data Entry, Form Filling, Copy Paste
# Hindi Typing| Typing| deo| fresher| data entry executive| data entry operator| English Typing| data entry| word| online data entry
#
# 8313 Microsoft SQL Server Database Developer
# ssis| ssas| power bi| ms sql server| etl| data warehousing| reporting tools| database development| database design| database architect| talend
#
# 8368 BigData Developer
# Unix| Analytical skills| Linux| SQL database| spark| Machine learning| Hadoop| Oracle| big data|Python
#
# 8387 BDB Big Data Engineer
# ERP| Team Building| Social media| Data analysis| Data mining| Ideas| MySQL| MS SQL| big data| Algorithms
#
# 8403 Oracle Application Database Administrator / Apps DBA
# Database Administration|RAC|Real Application Cluster|Cloning|Backup|Oracle DBA|Disaster Recovery|Patching|ASM|Apps DBA
#
# 8432 Senior Program Manager - Data Sciences
# PMP| Agile| Scrum| Product management| Machine learning| JIRA| Stakeholder management| RFP| Analytics| Automotive
#
# 8445 Technical Lead - Cloud, Java/Python, Databases
# database design|Python| java| software development| NoSQL| automation testing| agile development| object oriented programming| aws| SDLC| Query optimization
#
# 8448 Network Data Admin
# Troubleshooting| Device installation| Firewall| Network Administrator
#
# 8502 Data Analytics
# Core Java| RDBMS| Coding| metadata| PAAS| developing| Data quality| HBase| messaging| NoSQL| java| apache| cassandra| SCALA| applications
#
# 8568 Data Engineer - Ssis/ssas/sql Server
# Business Intelligence| SSAS| Big Data| SQL Server| Informatica| SSIS| Data Analytics| ETL| AWS| SQL
#
# 8633 Associate_Data Scientist
# Analytics| SQL| MS Office| Auditing| Financial services| Oracle| Data mining| Business operations| Asset management| Monitoring
#
# 8702 Rs.80k PM Part Time Work From Home 6 Type Data Entry & Handwriting Job
# bpo| computer operator| back office| lpo| hr| kpo| call center| part time| data entry operation| fresher| front office| typing| online| data entry operator| non voice| data entry| freelancer| ms office
#
# 8718 Data Analyst
# Supply chain| Excel| PDF| Database management| Analytical| Trend analysis| Data Analyst| Advanced Excel| Management| MS Office
#
# 8748 Digital Marketing Executive | SEO Analyst @ MNC Data Infovision Rewari
# digital marketing| css| it marketing| SEO Analyst| seo| SEO Expert
#
# 8752 Home Based SMS Sending Work Data Entry, Form Filling, Copy Paste
# freshers| data entry work
#
# 8758 Big Data- Assistant Professor
# Counselor| Mentor| Trainer| Advisor| Teaching
#
# 8878 Enovia Data Migration Specialist
# Enovia
#
# 8974 Microsoft SQL Server Database Developer
# T - SQL| SVN| MySQL| Database Development| GIT| RDBMS| MS SQL Server| Change Control| Technical Documentation| Control Testing| ssrs| SSIS| MSBI| Stored Procedures| Query Optimization| Indexing
#
# 8982 Database Engineer
# Supply chain| Computer science| ERP| Linux| Data management| Data structures| Stored procedures| Macros| Analytics| SQL
#
# 8983 Manager - Data Analytics
# SQL| Business objects| Business intelligence| Application support| Open source| Remedy| Consulting| Change management| Auditing| SPSS
#
# 9008 Urgent Opening with our client For Install Base & Data Analysis
# Excel| Data Analysis| Install Base
#
# 9016 Hiring Data Scientist Professionals in Hyderabad
# R| Time Series Analysis| Text Analytics| SQL| Machine Learning| Natural Language Processing| Finance| Data Science|Python| Forecasting
#
# 9030 Meter Data Management (mdm)
# meter data management|Billing|Manager Technology|Revenue management|Application Lead|Outsourcing|Oracle|Operations|Network management system
#
# 9031 Azure Data Architect - Data Warehousing
# Business Intelligence| Azure| Data Architect| Hadoop| Big Data| OLAP| Data Warehousing| ETL| Solution Architect| CTO| Predictive Analytics
#
# 9111 Executive - Customer Care - Data Entry - BPO
# bpo| international call center| bpo fresher| domestic bpo| call center| inbound| customer care| hindi| english| communication| non voice process| data entry| back office| non voice| fresher| telecalling| MS Office| ms excel| Tally ERP
#
# 9115 SAP Data Migration Consultant
# Data analysis| Data migration| Business analysis| Computer science| Business process| SAP implementation| Analytical| Back office| Data quality| Data extraction
#
# 9122 Datacenter Inventory & Asset Technician
# Healthcare| Logistics| Outbound| Supply chain| Data entry| microsoft| Inventory control| Support services| Inventory| Cloud Services
#
# 9144 Big Data Developer
# Core Java| JSON| Troubleshooting| Computer science| SOA| Analytical| SCALA| Hadoop| big data| GEL
#
# 9175 Application Lead - Aws/big Data
# Big Data| Presales| Data Warehousing| Data Analytics| AWS| RFP
#
# 9177 Data Scientist - Machine Learning/image Processing
# Speech Recognition| NLP| OpenCV| Image Processing| Spark| Computer Vision| Machine Learning| Deep Learning|Python
#
# 9207 BSc Walkin Drive (0-1yrs Exp) - Data Analysis Role - Koramangala
# Excel| Data Management| Data Analysis| Internet
#
# 9289 Master Data Management (talend / Kalido / Reltio / Others)
# Consulting|Data management|Data quality|Outsourcing|Data architecture|Operations|Master data management|C|Application Lead|telco
#
# 9343 Looking For Data Architect For New Jersey Location
# Java|Hive|Oracle SQL|SCALA|Unix Shell Scripting|Microsoft Azure|Spark|Data Modeling|ETL|AWS|Python
#
# 9399 Senior Consultant/ Data Integration Consultant - EPM
# Data Quality| EPM| System Design| ODI| Informatica| SSIS| Project Life Cycle| Data Integration
#
# 9434 Lead Analyst - Data Science
# SAS| SQL| data science|Python| Campaign management| technical| level| Business intelligence| tools| Supply chain| analytics| Business objects| database| optimization| Analytical| Consulting| design| SPSS| powerpoint
#
# 9441 Data Analyst
# Accessories| Data analysis| Google Analytics| Analytical| Machine learning| Data structures| Reporting tools| SQL| Logistics|Python
#
# 9447 Database Administrator
# channel business| Database Administrator
#
# 9488 SAP Master Data Governance
# Business process|SAP|Web technologies|Technical design|data governance|Manager Technology|Ale|Outsourcing|Operations|Object oriented programming
#
# 9497 Specialist - Database Administration
# development| dba| sql development| oracle| performance tuning| database administration| ocp
#
# 9535 Data Governance Senior Specialist
# Change management| Agile| SQL| Computer science| metadata| TOGAF| Analytical| data governance| Data quality| Data architecture
#
# 9590 Lead Administrator Database Infrastructure
# Performance tuning| Consulting| Trend analysis| Customer satisfaction| Customer management| Lead Administrator| Effort estimation| Database Administrator| Oracle admin| Vmware Administrator
#
# 9591 Senior/principal Data Scientist - KPO
# Machine Learning| Data Mining| Big Data| Data Science|Python| Data Management| Artificial Intelligence
#
# 9629 Meter Data Management (mdm)
# Oracle|Billing|Business process|Outsourcing|Operations|meter data management|Network management system|Revenue management|Manager Technology
#
# 9645 Database Developer - Sybase/oracle/db2/sql Server
# Oracle| SQL Server| DB2| Sybase| DB| deployment
#
# 9682 Data Visualization Specialists –Python + SQL – Accenture HYD
# Python|Big Data Analytics|data analytics|Cognos BI|data modeling|Data Analysis|data visualization|ssis|sql
#
# 9695 Data Scientist
# data science| Machine learning| Programming| Data quality| data visualization| big data| Statistics| SQL|Python
#
# 9726 Database Analyst
# Database Analyst
#
# 9742 Data Scientist
# Machine learning| Data mining| Principal component analysis| Statistical analysis| Factor analysis| Time series analysis| Arima| Finance| Statistics
#
# 9752 Big Data Engineer
# SQL|Python| Data structures| Graphics| Data analysis| QlikView| metadata| Data conversion| SCALA| Archiving
#
# 9799 Back Office / Data Entry / Computer Operator
# Help Desk| Customer Service| customer relationship| access controls| Asset Management| Vendor Management
#
# 9839 Data Engineer 3
# Performance tuning| Core Java| Data modeling| Coding| Scheduling| Agile methodology| Teradata| Distribution system| Financial services| SQL
#
# 9894 Big Data Developer
# Akka| Play Framework| Web Services| Docker| NoSQL| SCALA| Web Technologies
#
# 9987 Medical Data Reviewer (bangalore/thane) (mbbs/md Any Stream)
# project management| data management| md microbiology| customer service| customer focus| clinical data| mbbs| md pathology| trend analysis| md pharmacology
#
# 10148 Data Scientist/consultant - Machine Learning/statistical Modeling
# Data Science| Java| R| SAS| Scala| Statistical Modeling| PhD| Machine Learning|Python
#
# 10193 Marketing Data Analyst
# Product Management| Marketing Campaigns| Digital Marketing| Data Analyst| Digital Analytics| Deep Learning| R| Sales| Excel| Data Analysis| Data Modeling| Consumer Insights|Python
#
# 10228 Abintiio Data Warehouse Tech Lead/ Architect
# data science| Unix| HTML| Perl| Android| Shell scripting| Data modeling| RDBMS| Stored procedures| Analytics
#
# 10239 Data Analytics / Reporting/ Machine Learning
# analytics reporting| R| data analytics| SAS| operational risk| data visualization| Machine Learning| SQL
#
# 10316 Data Integrity Analyst - QL2
# Analytics| SQL| Coding| Analytical| Data collection| Computer science| PDF| data integrity|Python| Interpersonal skills
#
# 10373 Lead Data Science Engineer
# Analytics| Machine learning| Artificial Intelligence| Data modeling| data science| Software solutions| Technical Lead
#
# 10455 Big Data
# Networking| Apache| SQL| development| Hadoop| Architectural design| tools| cloud| java| Coding| Open source| big data| Virtualization| programming| Testing
#
# 10497 PMO Data Analyst
# Data analysis| SQL| Advanced Excel| Root cause analysis| Excel| MS Access| Data Analyst|Python| Database| VBA
#
# 10504 Data Engineer
# SQL| Automation| Data modeling| Scrum| OLAP| Manager Quality Control| Computer science| Machine learning| metadata| Forecasting
#
# 10551 Data Science - Freshers
# Data Science| Machine Learning
#
# 10630 Data Engineer III
# Business intelligence| Data analysis| Data migration| Monitoring| Auditing| DBMS| SQL Tuning| Data quality| Information management| data mapping
#
# 10692 Senior Network Data Administrator
# WAN| cisco| SSL| Monitoring| Intranet| Websense| ASR| Local area network| Workforce management| Quality management
#
# 10721 Database Analyst
# GIT| Stored Procedures| Shell Scripting| Ubuntu Linux| MySQL| SQL Queries| SVN| Version Control| Bash| AWS
#
# 10743 Big Data Engineer with Java & NodeJS
# J2Ee| Unix| Hibernate|Python| Performance tuning| Coding| Debugging| Agile methodology| Architectural design| big data
#
# 10745 Manager: Operations (Call Center/ Data Operations)
# data analysis| Customer Service| Help Desk| Information| Telephony support| customer relationship| access controls
#
# 10849 Job Opportunity @exponentia Datalabs for Front End Canvas Developer
# front end
#
# 10926 Scientific Data Associate/Executive
# toxicology| English| French| Word| Chemical| Microbiology| German| Biochemistry| Spanish
#
# 10934 Data Entry Operator
# Hindi Typing| customer calling| Typing| inbound| Non Voice Process| Calling| Backend Operations| Non Voice| Data Entry| Bpo Non Voice| Data Entry Operator| DEO| Backend| Back Office| Back Office Support
#
# 11086 Lead Data Scientist withPython and Pair Programming Skills
# Architecture| Cloudera| Hadoop| HDFS| Hive| NoSql| Cloud| Spark| Hbase
#
# 11091 Data Scientist
# deep learning| software architecture| C++| Networking| Database management| Management systems| Machine learning| big data| Data warehousing|Python
#
# 11146 Senior Backend Developer - Data Structure/algorithm
# Data Structure| Algorithm| MySQL| NoSQL| Redis| MongoDB| Couchbase| AWS| Docker
#
# 11147 Urgent Opening for Data Scientist role with a Leading MNC
# Deep Learning| Machine Learning| R|Python| Data Mining| Gradle| Subversion| Statistical Analysis| Design Analysis| Computer Science
#
# 11187 Data Entry (healthcare Domain) -leading Mnc-New York
# data entry| data entry operator| backend| back office
#
# 11221 Application Developer - Hadoop/big Data Ecosystem
# NoSQL| Hadoop| Cassandra| Big Data| MongoDB| Solution Design| Hbase| Analytics| MapReduce| HBase
#
# 11233 Computer Operator Data Entry Operator/ Typists Earn 2k-3k Daily No Fee
# bpo| back office| inbound| night shift| calling| data entry| mnc| data entry operator| Computer Operator| Office Assistance| Admin Executive
#
# 11275 Big Data Developer for Greater New York Location
# Spark| Hive| SQL| SCALA| Core Java| Sqoop| Big Data| Data Modeling
#
# 11345 Clinical Data Entry
# Customer Service| Help Desk| Information| Telephony support| customer relationship| access controls| Vendor Management| Asset Management
#
# 11379 Walk in for Back Office Process / Data Entry Operators
# typing speed| back office| data entry| backend| back office executive| back office operations| backend operations| Non Voice
#
# 11461 Data Engineer Jobcode Swtind250118 24
# SQL| Linux| MySQL| development| Email| Views| software| testing| it| UVM| quality| analytics| cloud| Backend| java| RDBMS| Machine learning| design|Python
#
# 11467 Data Scientist - Big Data &amp; Machine Learning Technologies/frameworks
# Data Science| Scala| Hadoop| Big Data| Spark| ETL| Machine Learning
#
# 11471 Excellent Opportunity for Fresher with Datamatics - Arizona.
# software development life cycle|BCA|fresher|it fresher|oops|mca|problem solving|bsc - it|analytical skills|communication skills
#
# 11486 Software Engineer - Data Science
# Data analysis| SQL|Python| Fund accounting| Machine learning| Support services| Asset management| QlikView| Monitoring| Financial services
#
# 11493 Lead Data Engineer
# Automation| Application development| Coding| Infrastructure management| Business process management| Artificial Intelligence| Genetics| SCALA| Lead Business Analyst| Technical Lead
#
# 11502 Senior Sales Executive - Data Science Platform
# Sales| Consulting Sales| B2B Sales
#
# 11542 Principal RWE Data Scientist
# Deep Learning| R| SAS| SQL Queries| Data Science| Machine Learning| Data Mining| Logistic Regression| Statistical Programming| Data Visualization| SQL
#
# 11564 Data Engineer
# Python| Web Crawling
#
# 11573 Analyst , Data Management & Quantitative Analysis
# asset servicing| Analyst| Data management| Analytical| Finance| Quantitative analysis
#
# 11627 Big Data Software Engineering Director
# Big Data| Hadoop| Spark
#
# 11650 Sr Database Developers
# Java| SOA| SaaS| Vertica| .net| OLAP| OLTP| Netezza.
#
# 11716 Business Data Analyst
# Computer science| MIS reporting| data services| Business Analyst| Rational rose| Analytical| Data quality| Visio| SQL
#
# 11764 Database Specialist (Oracle)
# development| java| oracle| btech| tuning| data modeling| computer science| hibernate| database administration| ba
#
# 11793 Data Management Executive
# Data Management| Advanced Excel| Macros
#
# 11826 Database Administration / dba ( Oracle & sql)
# backup| bi| sql tuning| plsql| sql| shipping| data modeling| rac| oracle dba| linux| sybase dba| sql developer| mirroring| rman| crm| oracle| sap| sybase| intel| oracle admin| shell| apps dba| asm| oracle sql| pl| ssis| unix
#
# 11851 Work Part Time for Data Entry | Computer Operator | Online Work
# bpo non voice| freelancing| online data entry| data entry| freelancer| back office| e - marketing| computer operator
#
# 11866 Data Scientist
# sql| oracle| sql server| mysql| configuration| workflow| stored procedures| functions| interfaces| data integration
#
# 11933 Data Analyst I
# Telecom| Data analysis| Excel| MS Outlook| Inspection| Database| Data Analyst| professional services| Research| Vendor
#
# 11942 Office Assistant Data Entry Operator,
# Accounting| Taxation| Back Office| Billing| ERP| Excel| Word| Data Entry
#
# 11949 Head – Credit Bureau Operations, Reporting & Data Warehousing – BFSI
# six sigma|process excellence|team management|BI|Banking|data migration|business intelligence|bfsi|cost optimization|operational excellence|Data Warehousing|credit bureau operations|Data Analytics
#
# 11994 Data Scientist, Advanced Analytics
# data science| machine learning|Python| algorithms| java| data visualization| advanced analytics| data analysis| data mining| Eta| R| Network Optimization
#
# 12007 Database Administrator
# Email| Views| Restoration| MySQL| Database| Configuring| Database Administrator| Troubleshooting| Monitoring| SQL
#
# 12009 Database Analyst - Stock Broking - Ahmedabad
# Database Maintenance| Stock Broking| insurance| MySQL| PHP| Laravel| financial services| banking
#
# 12048 Data Processor – Clinical Data Management -Arizona (thane) – (2-6 Years
# clinical research|data processing|clinical data management|ich - gcp
#
# 12092 Data Engineer
# SQL queries| Statistical analysis| Web technologies| Script writing| Hadoop| Analytics
#
# 12099 Senior ML Data Engineer
# Data Science| NLP| Statistical Modeling| Data Analysis| Perl| Data Modeling| Machine Learning| Deep Learning| Analytics|Python
#
# 12201 Amazon- Walk-in For Data Associate - English-20-july|phoenix Hitech
# fresher|english|typing
#
# 12208 Web Data Analyst
# Computer Savvy
#
# 12229 Senior Database Developer
# SQL Server| T - SQL
#
# 12250 Data/NLP Scientist
# C++| SQL|Python| Algorithms| Analytics| Customer service| Customer support| Computer science| Machine learning| Tools
#
# 12288 Big Data Developer Parkar Consulting &amp; Labs
# Unix| Computer science| SQL queries| Data analysis| Email| Consulting| Shell scripting| Educational qualification| Monitoring|Python
#
# 12299 Database Developer/Contract to hire/ Hyderabad
# jQuery| SSRS| Javascript| ASP.Net| SQL Server
#
# 12382 Data Architect
# Linux| Oracle DBA| Perl| Computer science| Version control| Analytical| Data Architect| PLSQL| Troubleshooting| Operations
#
# 12491 Sr. Database Developer
# Oracle| Db2| Software development life cycle| Leadership training| Management| Manager Technology| Database
#
# 12528 LDM (Lead Data Management)
# Data management| EDC| clinical data validation| Management consulting| Query management| Reconciliation| Manual| Management| Operations
#
# 12533 VP - Data Science/ Machine Learning - Credit Risk Domain
# matlab| technical architecture| r|Python| data science| sas| credit risk| machine learning| big data| product engineering
#
# 12551 SME - Database
# Troubleshooting| SQL| Database management| security compliance| Product Associate| remediation| OEM| Statistics| Auditing| Basic
#
# 12564 Data Scientist
# Consulting| Healthcare| Bfsi| Financial services| Outsourcing| Risk analytics| Enterprise risk management| Manager Technology| advanced analytics| risk compliance
#
# 12647 Data Engineer - Aryaka Bangalore
# hive| spark| hbase| pig| java| cassandra| big data|Python| mysql| mapreduce
#
# 12676 Data Scientist
# Design| R| Coding|Python| SQL
#
# 12689 Hiring For Data Entry & Computer Operator Jobs In Ohio New York Florida
# computer operator| Computer Operating| Calling| customer care| back office executive| Data Entry| customer support| deo| Back Office| typing| data entry operator| customer care executive
#
# 12724 Business Analyst (Datawarehousing):
# MS Office suite| Data analysis| Business Analyst| Business analysis| Mortgage| Writing skills| VISIO| Presentation skills| Data warehousing| SDLC
#
# 12727 Senior Database Administrator
# Performance tuning| Oracle DBA| Customer service| Oracle database| Disaster recovery| Banking| Cloud| Infrastructure| Database Administrator| Operations
#
# 12749 SQL Server Database Administrator (dba)
# Database Administration| Azure| Installation| SSRS| BI| SQL Server| Clustering| Server Monitoring| Database Maintenance| Mirroring| IIS| Data Modeling| Log Shipping
#
# 12768 Immediate Opening For Data Analyst/senior Data Analyst
# Unix| Hive| Linux| Data Analysis| Data Processing| Map| Athena| Data Domain| SQL
#
# 12833 Data Entry/non Voice/back Office/marketing- part time or full time
# non voice| back office| data entry| part time| marketing| fresher| Call Center| BPO| Front Office| HR| Sales| Online| E - commerce| Freelancing| Content Writing| IT Management
#
# 12850 Data Engineer: Enterprise Content Management
# enterprise content management| agile process| business analysis| technical management| project execution| Agile| Scrum| FileNet
#
# 12957 Data Scientist - NLP Systems - BFSI
# Natural Language Processing| Deep Learning| NLP| Neural Networks
#
# 13107 Data Processing Associate
# Senior Design Engineer| Typing| Science| Paint shop
#
# 13213 Consultant DMS SAP Master Data
# SD| MM
#
# 13226 Data Entry | Back Office Executive | Fresher | Computer Operator
# BPO| Hiring| LPO| call center| KPO| Data Entry| bpo call center| Communication Skills| Backend| bpo fresher| Bpo Voice| chat| Domestic| Domestic BPO| bpo executive| international call center| International BPO
#
# 13250 Datacom Testing
# Automation testing| Test reporting| IXIA| Spirent| Regression testing| Bug reporting| Perl| cisco|Python| Scripting
#
# 13362 MS SQL Database Administrator (4+ Years Experience
# MS SQL| Db2| L2| SQL DBA
#
# 13418 Database Administrator
# MS SQL| Database design| SQL Database Administrator| Test management| MySQL| query| Database| Management| Database Administrator| Testing
#
# 13457 Senior Data Engineer
# Python| web services| oozie| microsoft azure| nosql| java| mapreduce| hdfs| sqoop| api| big data| aws| scripting languages| azure
#
# 13482 Lead - Data Engineering
# Computer science| Telecom| Coding| Information security| ISO 27001| OLAP| Troubleshooting| Distribution system|Python
#
# 13609 Big Data - Developer : Hyderabad
# Hadoop| SSRS| MS SQL Server| Spark| Data Warehousing| Tableau| Data Modeling| SSIS| ETL| T - SQL
#
# 13702 Informatica Datastage Developer
# Informatica| datastage| Data Management
#
# 13952 Data Analyst
# machine learning| sql|Python| r| hadoop| tableau| algorithms| analytics| customer segmentation| business intelligence| data analyst
#
# 14010 Database Associate / Analyst
# ...
#
# 21642 Assistant Manager - Data Warehousing & Business Intelligence
# Business Intelligence| Visualization| Power BI| Data Management| Qlikview| Data Warehousing| Tableau
#
# 21729 Java Technical Architect - Data Structure/algorithm
# Technical Architect| Java| J2EE| Product Management| Data Structure| Algorithm
#
# 21830 BPO Call Center (freshers) ~ Data Entry Operators ~ Apply Now
# bpo| Inbound Process| non voice process| customer care| call center| customer support| domestic| voice process| voice support| calling| international call center| Fresher| customer care executive
#
# 21939 Excellent Opportunity for SAP Data Service-bangalore
# SQL| Data Profiling| ETL| Data Quality| Sap Data Services| Performance Tuning| Problem Solving| Quality Tools
#
# 22036 Oracle Database Administrator
# Database Administration| Linux| Networking| Patch Management| Backup| Oracle DBA| Oracle RAC| ASM| Restore| SQL
#
# 22043 Data lake Engineer
# Big Data| Hadoop| Open Source| Automation
#
# 22109 DBA - Database Administrator
# Performance tuning| MS SQL| Disaster recovery| Database| Windows| Database Administrator| Active Directory| Verbal communication| SQL| SQL Server administration
#
# 22159 Database Operations (Operations (Tech))
# Unix| Perl| Shell scripting| Automation|Python| Troubleshooting| Problem management| Scheduling| Powershell| Operations
#
# 22239 Big Data Engineer
# Service| ERP| Team Building| Social media| Data analysis| Data mining| Ideas| MySQL| MS SQL| big data
#
# 22321 HCL Technologies is Hiring For Data Scientist Position in New York
# deep learning| data management| data science| natural language processing| regression| machine learning| classification| neural network
#
# 22330 Data Entry Operators cum Telecaller
# Entry| Email| CV| Image processing| Time management| Analytical| Back office| Web designing| Data Entry Operator| Data entry
#
# 22430 Work@home | Part Time | Data Entry | Computer Operator | Online Work
# part time| back office| data entry| digital marketing| fresher| bpo| sales| marketing sales| Freelancing| B Tech
#
# 22447 Data Entry Operator (deo)
# inbound| customer calling| Data Entry| Backend Operations| Back Office| Back Office Support| Backend| Bpo Non Voice| Non Voice| Non Voice Process| Typing| Hindi Typing
#
# 22464 Data Management Admin II
# Market Data|Service Level|Fund Accounting|Reference Data|Finance|Reconciliation|Data Management|Corporate Actions|MS Office|Investment Products
#
# 22506 Oracle Database Administrator&amp;weblogic Administration
# Exadata| Weblogic Administration| Database Administration| Oracle Database| Oracle DBA| Performance Tuning
#
# 22545 Application Lead - AWS/ Big Data/ Redshift
# Cloud| Big Data| Data Warehousing| Data Analytics| AWS
#
# 22701 Data Analytics (CSE) - Associate Professor
# Counselor| Mentor| Trainer| Advisor| Teaching
#
# 22754 Sr . Oracle Developer - Data
# PLSQL| Analytics| Salesforce| Order management| Computer science| RCA| Data migration| Analytical| data governance| Data quality
#
# 22927 Data Entry Operator|back Office|call Center|computer Operator
# Computer Operator| Typing| data| Non Voice Process| Non Voice| Voice Process| Data Entry| Inbound| Data Entry Operator| Backend| Domestic Voice Process| Domestic| Back Office| Fresher| Call Center| Voice| Data Entry Operation| International BPO
#
# 22971 Position Data Scientist
# assembly language| JavaScript| .NET| HTML| Oracle|Python| SQL
#
# 23243 Back Office / Data Entry Operator
# bpo| domestic bpo| international bpo| bpo voice| back office| bpo backoffice| call center| kpo| blended process| bpo executive| backend| non voice| ITES| bpo hiring| bpo operations| data entry| bpo non voice| telemarketing
#
# 23308 Opening For Azure Data Factory ETL & Azure Cloud_New Jersey
# Azure
#
# 23314 Data Scientist
# Data analysis| Forecasting| Data collection| Investment management| Machine learning| Text mining| Computer science| Agile| Investment| deep learning
#
# 23424 Clinical Data Programmer
# Biometrics| CRO| SAS| EDC| Clinical trials| clinical development| Clinical research| Life sciences| Oracle| Clinical data management
#
# 23443 Co-founder/ Chief Data Scientist/ Senior Data Scientist
# Data Science| Data Management| Predictive Modeling| Big Data| Artificial Intelligence|Python| Machine Learning| PhD
#
# 23461 Business Analyst - Power BI, Tableau, SQL and Data Analytics ( Male )
# bpo| data analytics| information technology| isp| operation team| digital strategy| power bi| it| kpo| business analyst| business tools| tool| sql| tableau| quality assurance| user acceptance testing| business continuity| telecom
#
# 23596 Freshers/ BPO / Call Center / back Office / Data Entry
# Bpo Non Voice| Call Center| International BPO| Back Office| Data Entry| Calling| Domestic| inbound| voice| bpo| kpo| lpo| Backend| fresher
#
# 23631 Senior Clinical Data Manager
# User Acceptance Testing|data management|Clinical Data Manager|Clinical Data Management|Drug Development
#
# 23708 Data Engineer
# MS SQL Server| Shell Scripting| Data Architecture| Data Quality| Database Administration| Data Management| Business Analytics| Third Party| ETL| SQL| MYSQL|Python
#
# 23769 Java Big Data Developer
# Unix| Linux| SQL| Maven| Hibernate| Core Java| Workflow| Agile methodology| Informatica| ExtJS
#
# 23838 Machine Learning Engineer - Big Data/hadoop
# Java| OpenCV| Scala| Hadoop| Big Data| Spark| Machine Learning| Algorithm|Python
#
# 23841 Senior Java Engineer - Data Structure/algorithm
# Core Java| Hibernate| Tomcat| Rest| Websphere| Design Patterns| Weblogic| Spring Boot| J2Ee| SOAP
#
# 23870 Datastage
# Datastage
#
# 23900 Java Developer (with Elastic Search & Nosql Database)
# data integration| rest| elastic search| soap| java| cassandra| postgre| nosql
#
# 23913 Capital Management - Data Governance - Sr. Associate
# technology| finance| operations| human resources
#
# 23954 Senior Data Scientist - Digital Marketing
# digital marketing| customer segmentation| life cycle| product management| customer research| competitive intelligence| customer retention| campaign analytics| telemarketing
#
# 23957 Senior Software Engineer - Data Management
# Python| Performance testing| SAN| Selenium| Analytics| Data management| GIT| French| SCALA
#
# 24042 Looking for Database Administrator (dba) for Software Company
# SQL Queries| Replication| Database Design| Stored Procedures| Performance Monitoring| Database Administration| Data Mining| Design Review| Capacity Planning| System Maintenance
#
# 24262 Data Center Engineer/architect
# Ccie|Networking|Ddos|Juniper|CCNA|Routing Protocols|CCNP|Network Architecture|Fortinet|MPLS
#
# 24320 Python Data Engineer - Web Scraping
# XML| Data Management| JSON| API|Python
#
# 24339 Data Scientist
# SQL| microsoft| Data mining| Analytical| Apache| Open source|Python| Machine learning| NoSQL| deep learning
#
# 24343 Senior Consultant_big Data/java
# Java| Hive| NoSQL| Sqoop| consultant| Cloudera| Hadoop| Oozie| Spark| Pig| HBase
#
# 24377 Data Migration Expert, Data Migration Consultant, Data Migration
# troubleshoot| server| software| testing| implementation| project| data migration| it| sql| database| consultant| web| migration| troubleshooting| mysql
#
# 24405 Senior Data Scientist
# data science| HTML| Android| Computer science| Data structures| Test cases| Open source| Data mining| MATLAB| Analytics
#
# 24419 Data Scientist
# Business intelligence| SQL|Python| Operations research| Analytical| Machine learning| SCALA| data visualization| Data mining| Statistics
#
# 24422 Lead Data Scientist / Project Manager Analytics Services
# Consulting| Analytics| Supply chain| customer analytics| Marketing analytics| digital analytics| Data analytics| advanced analytics| Pilot| Solution design
#
# 24465 Senior Manager - Big Data
# Azure| Hadoop| Cloud| Big Data| Spark| Solution Design| AWS| Algorithm
#
# 24517 BigData Engineer @ ERD
# Computer science| JMS| Maven| Interpersonal skills| Automation| Data management| Packaging| Data structures|Python| Data architecture
#
# 24523 Opportunity For Data Infrastructure Enginer Leadwith Captive In Arizona
# java| db2| teradata| Hadoop| linux| shell Scripting| perl| informatica
#
# 24543 Solution Architect- Big Data
# Engagement Management| Client Management| Project Estimation| Resource Planning| Project Management| Waterfall| Agile| Project Delivery| Data Modeling| big data| Business Analysis
#
# 24760 Sr. Grp Mgr, Data Governance
# SDLC| Business analysis| Investment banking| Technical writing| Information technology| Monitoring| Data management| Computer science| Financial services| metadata
#
# 24765 Position Data Scientist
# assembly language| JavaScript| .NET| HTML| Oracle|Python| SQL
#
# 24837 Data Scientist - Machine Learning/algorithm
# Data Science| R| Data Management| Big Data| Data Mining| Machine Learning| Algorithm|Python
#
# 24874 Lead Data Scientist - Machine Learning
# Data Science| Data Management| Machine Learning| System Design| GPS
#
# 24891 Data Analyst - Sql/r/Python
# R| Data Analyst| Data Analytics|Python| SQL
#
# 25085 Opening for Lead Data Engineer in US Based MNC for Florida Location
# SQL Server| MSBI| Azure| Team Management
#
# 25182 Data Analyst
# Excel| Data Analysis| SAS| XML| Data Mining| SQL| Data Analytics| Statistics| Segmentation| Data Collection
#
# 25193 Data Engineer II
# Automation| metadata| technical| Perl| Business intelligence| Data mining| Unix shell scripting| Computer science| infrastructure| design| e-commerce| Risk management| Ruby| support|Python| architecture| hardware
#
# 25266 Data Entry Operators ( Junior process Executives )
# coordination| documentation| record keeping| dispatch| forms| registration| scanning| back office operations| mis preparation
#
# 25277 Senior Software Engineer - Java, Big Data at Informatica
# Computer science| Version control| Debugging| Disaster recovery| Agile| Healthcare| Life sciences| Informatica| Unit testing| Financial services
#
# 25288 Microsoft Modern Data Platform
# Business process| Coding| Programming| Outsourcing| Business intelligence| Cosmos| Operations| Analytics| Analysis services| SQL
#
# 25341 Data Entry Operator / Catalog Uploader cum Tele Caller Work From Home
# data entry| computer operating| calling| customer care| customer support| customer care executive| computer operator| back office| back office executive| data entry operator| typing| deo| fresher
#
# 25350 Big Data Engineer
# Java| Hibernate| Rest| SCALA| Big Data| J2Ee| Spark| Spring|Python
#
# 25385 Administrator - Database | Microland
# Oracle| Unix| Database| MS SQL| Data management| Performance tuning| Coding| Database migration| Customer service orientation| Monitoring
#
# 25395 Sr. Database Developer
# SQL| Automation| Troubleshooting| Data modeling| RDBMS| Product management| Monitoring| Computer science| Account management| Schema
#
# 25476 Director - Data Science
# Data Science|SAS|Customer Experience|User Experience|Digital Marketing|Campaign Management|Statistical Programming|SPSS|Statistical Analysis|Machine Learning|MATLAB|Cluster Analysis
#
# 25481 Analyst - Finance and Risk Data Operations
# operations| technology| human resources| finance
#
# 25482 Data Analyst
# Automation| Ticketing| Database design| Data quality| data visualization| SQL|Python| Auditing| Data architecture| data profiling
#
# 25530 Data Analyst - R/sas/sql
# Data Analytics| Data Analyst| SQL| SAS| R| Google Analytics| Data Mining| Algorithm
#
# 25684 Senior Consultant - Cloud Data & Analytics Developer
# Distribution System| Management Services| Shell Scripting| Continuous Integration| Data Structures| Data Analysis| Application Integration| Data Modeling| Data Analytics| SQL
#
# 25727 Data Analyst
# Visual Basic| MySQL| Data Analyst| KPO| Business Objects| Oracle| Business intelligence| Macros| Analytics| SQL
#
# 25809 Big Data Developer
# Azure|Python| Big Data| Tableau| Pig| Hive| R| NoSQL| SCALA| Spark| QlikView| AWS
#
# 25847 Urgent Opening for Data Analyst (pms) at Greenpoint Global at Belpur
# Data Analysis| Data Collection| Project Management
#
# 25849 Data Analyst(accounts and Audit) - Freight Industry
# financial analysis| Audit| data analysis| data processing| auditing| accounting| statistical analysis| Accounts
#
# 25893 Data Modeling Techniques and Methodologies
# SQL Server|Big Data|Data Modeling|Performance Tuning|Project Delivery
#
# 25964 Backend Developer - Big Data
# Big Data| Hadoop| Spark| Cassandra| MongoDB| Java| C#| Data Management| Cloud
#
# 25977 Jr Data Analyst
# Data Analysis
#
# 25988 Data Scientist
# Data analysis| Project management| SQL| Mining| Factor analysis| Google Analytics| Web analytics| Omniture| Project delivery|Python
#
# 26024 Urgent Requirement for Data Analysts in a Leading MNC in Arizona
# Advanced Excel| Macros| VBA| MIS Reporting| Data Analysis| Night Shift| Dashboards
#
# 26035 Developer Enterprise Data Integration
# Unix shell scripting| Oracle data integrator| Programming| Manager Technology| Mentor| c| oracle| development| technical| unix| software| application| developer| ui| com| pl| support| scripting| it
#
# 26038 Lead - Data Analytics
# Logistic regression| SAS| Project management| Business analytics| Analytical| Data processing| Data mining| Financial services| SQL| Data extraction
#
# 26060 Work Flexibly IN YOUR HAND You Can TYPE ANY TIME Offline|online Data E
# back office| data entry| digital marketing| fresher| bpo| sales marketing| sales & marketing| Freelancing| freelancer| under graduate
#
# 26088 Data Analytics Principal
# Project management| Data analysis| SQL| SAS| Forecasting| Supply chain| Data mining| Operations research| Analytical| Operations
#
# 26199 Data Engineer: Big Data
# scrum| business analysis| agile process| big data| project execution| data cleansing| ETL
#
# 26239 Excellent Opportunity as a Tech Lead with Datamatics - Arizona
# Requirement Gathering|UML|C|Design Patterns|Technical Architecture|Rational Rose|Software Development|Business Analysis|.NET Framework|Project Tracking|OOPS|.net core|sql|azure
#
# 26293 Lead Data Scientist
# SAS| Natural Language Processing| Big Data| Machine Learning| Deep Learning| SQL| R| Algorithms| Opencv| Spark| Computer Vision|Python
#
# 26295 Database Administrator - Sybase
# DBA| Security| DB| Sybase
#
# 26353 Data Entry Jobs,work From Home, Part Time Jobs, Online Form Filling
# hr recruiter| screening| recruiter| mass hiring| bulk hiring| hr| Data Entry| HR Manager| bpo recruiter| recruitment consultant| recruitment| recruitment executive| headhunting| bpo hiring| bulk recruitment
#
# 26431 ACN – Digital – Analytics – Data Services – 9
# R|Hive|Segmentation|Linear Regression|Spark|Tableau|Machine Learning|Statistics|Deep Learning|Python
#
# 26494 Data Integration Consultant - Pentaho
# Data Integration| Pentaho| Data Management
#
# 26636 Requirement for Data Science/ Data Analyst New York-2-6 year Experience
# Python| django| machine learning| sql| Data Science| Predictive Analytics| Statistical Analysis| Data Extraction| Data Cleansing| Linear Regression| Logistic Regression| Data Mining
#
# 26716 Senior Lead - Production Support - Data Management - IT
# Data Management| Agile| Scrum
#
# 26728 Associate Professional Database Administrator
# Computer science| Analytical| Operations| technical| Database design| Database management| Data structures| Database Administrator| tools| tracking| database| infrastructure| design| Database administration| support| programming| hardware
#
# 26734 Datapower Consultant For Immediate Joiner Contract To Hire
# Application Development| SOA| Networking| Web Technologies| Application Integration| SOAP| Datapower| Data Center| Web Services
#
# 26757 Financial Data Analyst
# Monthly Reports| Balance sheet| Finance| general accounting| Data Quality| Reconciliation| Data Analysis| General Ledger| trial balance| Test Cases| Data extraction
#
# 26846 Data Scientist
# Product engineering| Analytical| Machine learning| Open source| Data mining| Business solutions| Analytics| Monitoring| SQL|Python
#
# 26915 Stenographer / Data Entry Operator
# SMS| Data Entry Operator| management| Executive search| Office Coordinator| query| Management Executive| Cloud
#
# 26980 Senior Developer (Big Data)
# java| SCALA| Spark| SQL| Hadoop
# ('Data', 580)

# %%
# All Key Skills
k = []
for i in range(len(data)):
    for j in data[i]["Key Skills"].split("|"):
        j = j.strip().upper()
        k.append(j)

print(len(set(k)))
print(set(k))
# Out:
# 14194
# {'', 'ICH', 'SDET', 'INTERACTIVE VOICE RESPONSE', 'MERCHANDISING STRATEGIES', 'CYCLE TIME REDUCTION', 'SALON MANAGER', 'DQA', 'ARCHITECTURAL DESIGN', 'CIVIL SUPERVISOR', 'SAP CONSULTANT', 'MASS SPECTROMETRY', 'INSTRUCTIONAL DESIGN', 'DISABILITY INSURANCE', 'APACHE SPARK', 'PPT', 'PRODUCT DEVELOPMENT MANAGER', 'SENIOR PROJECT MANAGER', 'PRE - PRODUCTION', 'AUTOMOBILE', 'WORKDAY', 'SERVICES MARKETING', 'CREDIT MANAGER', 'ZLD', 'TELE-CALLERS', 'OPERATIONS TEAM HANDLING', 'SUSTAINABILITY', 'BLOOD COLLECTION EXECUTIVE', 'PURCHASE VENDOR DEVELOPMENT', 'PROCESS PLANNING', 'PRODUCT & TRAINING', 'CUSTOMER OPERATIONS', 'TOUR', 'DISTRIBUTOR DEVELOPMENT', 'RATE ANALYSIS', 'PROCESS DEFINITION', 'CHEMICALS', 'LINUX SYSTEM ENGINEER', 'FIXTURES', 'JES2', 'ENERGY', 'SCHOOLS', 'PRINTING & PACKAGING', 'WINDOWS SERVER ADMIN', 'EXECUTIVE DIRECTOR', 'P&C', 'SENIOR RELATIONSHIP MANAGER', 'VENDOR QUALITY', 'CAPA', 'RADIOLOGY TECHNICIAN', 'ADVANCE TAX', 'ASSISTANT CAFE MANAGER', 'FULL STACK DEVELOPER SAP CONVERSATIONAL AI', 'DATA DOMAIN', 'MAPREDUCE', 'LEARNING & DEVELOPMENT', 'CANT', 'MCP', 'CREDIT OFFICER', 'XENMOBILE', 'BSP CUSTOMIZATION', 'HVAC ENGINEER', 'CONSTRUCTION OPERATIONS', 'HEAVY VECHICLE', 'CREDIT MONITORING', 'OFFICE 365', 'VISA COUNSELLING', 'CNC MAINTENANCE', 'PACS', 'BANK AUDIT', 'REGIONAL REPRESENTATIVE', 'REVIT MEP', 'GERMAN LANGUAGE', 'BIOINFORMATICS', 'LINUX SYSTEM ADMINISTRATION', 'GENEVA', 'FRONT OFFICE MANAGEMENT', 'CUSTOMER SALES EXECUTIVE', 'PROJECT OPERATIONS', 'CASUALTY', 'PASSPORT', 'SECURITY', 'CREDIT RISK ANALYSIS', 'TWO WHEELER LOANS', 'IEEE', 'SOSL', 'CONSTRUCTION PROJECTS', 'QUALITY CONTROL', 'WINDOWS SERVER SUPPORT', 'SOFTWARE DEVELOPMENT ENGINEER', 'TECH MAHINDRA', 'TRANSLATION ASSOCIATE I', 'RECRUITING', 'AUTOMOTIVE LIGHTING', 'COLUMNS', 'PERSONAL CARE', 'SMB', 'EMPLOYEE DEVELOPMENT', 'PHARMACIST RETAIL / HOSPITAL', 'COMP', 'GAUGE', 'SDL TRIDION', 'ACCOUNT OFFICER - INSURANCE', 'COSTING EXECUTIVE', 'PROJECT ADMINISTRATOR', 'PROCESS SETTING', 'REWORK', 'MANAGEMENT MARKETING', 'PRESENTATION SKILL', 'EQUITY FUNDS', 'EXIM POLICY', 'FMCD', 'ANALYST', 'CSE VOICE', 'DATA MAPPING', 'PROCESS DESIGN AND IMPROVEMENT', 'HEALTHCARE CONSULTING', 'IN - DESIGNING', 'YUM', 'GUIDING', 'ELECTRICAL TECHNICIAN', 'OFFICE CO - ORDINATOR', 'DATABASE MIGRATION', 'PROMOTIONAL CAMPAIGNS', 'HIGHWAY ENGINEERING', 'BE.BTECH', 'CASH FLOW', 'DIRECT CLIENT', 'COMPUTER NETWORKING', 'DEVOPS ENGINEER', 'CIRCUIT DESIGNING', 'OPERATION EXECUTIVE', 'COMPLIANCE MANAGEMENT', 'FOODS RAW MATERIAL', 'CLEAR QUEST', 'ITI ELECTRICAL', 'ADS', 'CHILLERS', 'FLAVOURIST', 'HOD', 'INTEGRATION TESTING', 'LEAD ADMINISTRATOR', 'CSS2', 'AFTER MARKET', 'BACKGROUND SCREENING', 'CONTRACTOR', 'EQUITY SALES', 'HELM', 'INTEGRATION', 'INVESTMENTS', 'PRODUCT DESIGNER', 'EVENT OPERATION', 'UNIT MANAGER - INVESTMENT', 'GENERAL MANAGER HR', 'ONLINE STORE MANAGER', 'FURNACE', 'ARCHITECT', 'MARKETING STRATEGIES', 'MULTILOAD', 'ELECTRICAL MAINTENANCE', 'FUNCTIONAL CONSULTANCY', 'ANALYTICAL RESEARCH & DEVELOPMENT', 'PROXY', 'CROSSCHECK', 'LNG', 'VAULT', 'ORACLE INTERNET DIRECTORY', 'TERRITORY EXECUTIVE', 'T&E MANAGEMENT', 'PROGRESS4GL', 'ASP NET', 'PERFORMANCE APPRAISAL SYSTEM', 'FRONTEND (UI)', 'HFM', 'NETWORK INTEGRATION', 'DIGITAL COMMUNICATION', 'CROSS SELL', 'SOLUTIONS ARCHITECTURE', 'DATA CLEANSING', 'HOSPITALITY MANAGEMENT', 'EXECUTIVE ASSISTANT AND FRONT OFFICE AND DATA ENTRY', 'MAPPING', 'ITINERARY', 'ENGLISH WRITING', 'COMPANIES ACT', 'FINANCIAL ADVISOR', 'FLYERS', 'GAMP5', 'ANVISA', 'CEMENT', 'APPAREL MERCHANDISING', 'FINANCIAL REPORTING', 'COACHSOFTWARE DEVELOPMENT', 'E - TENDERING', 'PSPICE', 'FUNDS', 'STRATEGIC BRAND MANAGEMENT', 'PGT CHEMISTRY', 'LEAD', 'MQL', 'OOZIE', 'ENTREPRENEURSHIP', 'EXTERNAL COMMUNICATIONS', 'AUTOMATION', 'MIS REPORTS', 'MOBILISATION', 'FIRSTSOURCE', 'UI DESIGN', 'TEAM DEVELOPMENT', 'JAX-RPC', 'FTA', 'ANESTHESIA CODER', 'CASA SALES OFFICER', 'TOWER CRANE', 'DIAGNOSTICS', 'ICP', 'OCCUPATIONAL HEALTH', 'JAVA CODING', 'PROCESS EQUIPMENT', 'HDL', 'WO ...

# %%
jobs_list = ["C", "C#","C++", "Java", "JavaScript", "Python", "Scala", "Oracle", "SQL Server", "MySQL Server", "PostgreSQLappend", "MongoDB"]
location_list = ['San Francisco', 'Philadelphia', 'Baltimore', 'Austin', 'Los Angeles', 'New York', 'Washington DC', 'Houston', 'New Orleons', 'Dallas', 'Detroit', 'Seattle', 'Boston']
jobs = []
loc = []
for i in jobs_list:
    #print(get_number_of_jobs_T(i))
    jobs.append(get_number_of_jobs_T(i))
print("List of jobs with number of jobs : \n", sorted(jobs, key=lambda x : x[1]))

print("\n")

for i in location_list:
    #print(get_number_of_jobs_L(i))
    loc.append(get_number_of_jobs_L(i))
print("Number of jobs with locations : \n", sorted(loc, key= lambda x : x[1]))
# Out:
# List of jobs with number of jobs :
#  [('MySQL Server', 0), ('PostgreSQLappend', 0), ('Scala', 33), ('MongoDB', 174), ('SQL Server', 250), ('C++', 305), ('C#', 333), ('JavaScript', 355), ('Oracle', 784), ('Python', 1173), ('Java', 2609), ('C', 13498)]
#
#
# Number of jobs with locations :
#  [('Philadelphia', 41), ('Austin', 434), ('San Francisco', 435), ('Los Angeles', 640), ('New Orleons', 817), ('Dallas', 1208), ('Baltimore', 1263), ('Boston', 2966), ('New York', 3226), ('Houston', 3339), ('Seattle', 3375), ('Detroit', 3945), ('Washington DC', 5316)]

# %%
jobs_loc = []
for i in jobs_list:
    for j in location_list:
        jobs_loc.append(get_number_of_jobs_J_and_L(i,j))
print(jobs_loc)
# Out:
# [('C', 'Los Angeles', 296), ('C', 'New York', 1622), ('C', 'San Francisco', 214), ('C', 'Washington DC', 2664), ('C', 'Seattle', 1668), ('C#', 'Los Angeles', 5), ('C#', 'New York', 41), ('C#', 'San Francisco', 3), ('C#', 'Washington DC', 68), ('C#', 'Seattle', 49), ('C++', 'Los Angeles', 3), ('C++', 'New York', 43), ('C++', 'San Francisco', 3), ('C++', 'Washington DC', 55), ('C++', 'Seattle', 41), ('Java', 'Los Angeles', 43), ('Java', 'New York', 326), ('Java', 'San Francisco', 38), ('Java', 'Washington DC', 516), ('Java', 'Seattle', 354), ('JavaScript', 'Los Angeles', 7), ('JavaScript', 'New York', 51), ('JavaScript', 'San Francisco', 7), ('JavaScript', 'Washington DC', 61), ('JavaScript', 'Seattle', 52), ('Python', 'Los Angeles', 24), ('Python', 'New York', 143), ('Python', 'San Francisco', 17), ('Python', 'Washington DC', 258), ('Python', 'Seattle', 133), ('Scala', 'Los Angeles', 0), ('Scala', 'New York', 8), ('Scala', 'San Francisco', 0), ('Scala', 'Washington DC', 3), ('Scala', 'Seattle', 4), ('Oracle', 'Los Angeles', 17), ('Oracle', 'New York', 95), ('Oracle', 'San Francisco', 19), ('Oracle', 'Washington DC', 143), ('Oracle', 'Seattle', 110), ('SQL Server', 'Los Angeles', 3), ('SQL Server', 'New York', 36), ('SQL Server', 'San Francisco', 2), ('SQL Server', 'Washington DC', 53), ('SQL Server', 'Seattle', 31), ('MySQL Server', 'Los Angeles', 0), ('MySQL Server', 'New York', 0), ('MySQL Server', 'San Francisco', 0), ('MySQL Server', 'Washington DC', 0), ('MySQL Server', 'Seattle', 0), ('PostgreSQL', 'Los Angeles', 0), ('PostgreSQL', 'New York', 1), ('PostgreSQL', 'San Francisco', 0), ('PostgreSQL', 'Washington DC', 3), ('PostgreSQL', 'Seattle', 1), ('MongoDB', 'Los Angeles', 2), ('MongoDB', 'New York', 25), ('MongoDB', 'San Francisco', 2), ('MongoDB', 'Washington DC', 32), ('MongoDB', 'Seattle', 21)]

# %% [markdown]
# ### Store the results in an excel file

# %% [markdown]
# Call the API for all the given technologies above and write the results in an excel spreadsheet.

# %% [markdown]
# If you do not know how create excel file using python, double click here for **hints**.
#
# <!--
#
# from openpyxl import Workbook        # import Workbook class from module openpyxl
# wb=Workbook()                        # create a workbook object
# ws=wb.active                         # use the active worksheet
# ws.append(['Country','Continent'])   # add a row with two columns 'Country' and 'Continent'
# ws.append(['Eygpt','Africa'])        # add a row with two columns 'Egypt' and 'Africa'
# ws.append(['India','Asia'])          # add another row
# ws.append(['France','Europe'])       # add another row
# wb.save("countries.xlsx")            # save the workbook into a file called countries.xlsx
#
#
# -->

# %% [markdown]
# Create a python list of all locations for which you need to find the number of jobs postings.

# %%
#your code goes here
for i in location_list:
    loc.append(get_number_of_jobs_L(i))
print("Number of jobs with locations : \n", loc)
# Out:
# Number of jobs with locations :
#  [('Los Angeles', 640), ('New York', 3226), ('San Francisco', 435), ('Washington DC', 5316), ('Seattle', 3375), ('Los Angeles', 640), ('New York', 3226), ('San Francisco', 435), ('Washington DC', 5316), ('Seattle', 3375)]

# %% [markdown]
# Import libraries required to create excel spreadsheet

# %%
# your code goes here
from openpyxl import Workbook, load_workbook

# %% [markdown]
# Create a workbook and select the active worksheet

# %%
# your code goes here
wb = Workbook()
ws = wb.active

# %% [markdown]
# Find the number of jobs postings for each of the location in the above list.
# Write the Location name and the number of jobs postings into the excel spreadsheet.

# %%
#your code goes here
ws.title = "Jobs&Locs"
ws.append(["Technology", "Location", "Num_of_Jobs"])
jobs_loc = []
for i in jobs_list:
    for j in location_list:
        jobs_loc.append(get_number_of_jobs_J_and_L(i,j))
        ws.append([get_number_of_jobs_J_and_L(i,j)[0], get_number_of_jobs_J_and_L(i,j)[1], get_number_of_jobs_J_and_L(i,j)[2]])
#print(jobs_loc)

# %% [markdown]
# Save into an excel spreadsheet named 'job-postings.xlsx'.

# %%
#your code goes here
wb.save("job-postings.xlsx")

# %% [markdown]
# #### In the similar way, you can try for below given technologies and results  can be stored in an excel sheet.

# %% [markdown]
# Collect the number of job postings for the following languages using the API:
#
# *   C
# *   C#
# *   C++
# *   Java
# *   JavaScript
# *   Python
# *   Scala
# *   Oracle
# *   SQL Server
# *   MySQL Server
# *   PostgreSQL
# *   MongoDB

# %%
# your code goes here

# %% [markdown]
# ## Author

# %% [markdown]
# Ayushi Jain

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja
#
# Lakshmi Holla
#
# Malika

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2022-01-19        | 0.3     | Lakshmi Holla     | Added changes in the markdown      |
# | 2021-06-25        | 0.2     | Malika            | Updated GitHub job json link       |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
# Copyright © 2022 IBM Corporation. All rights reserved.
